# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    age  gender department  experience  salary       city education
# 0   21    Male         IT           1   20000    Chennai        UG
# 1   23  Female         HR           2   25000    Chennai        UG
# 2   25  Female         IT           3   30000  Bangalore        UG
# 3   30    Male    Finance           5   40000    Chennai        PG
# 4   35    Male         IT           7   50000      Delhi        PG

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         20 non-null     int64
#  1   gender      20 non-null     object
#  2   department  20 non-null     object
#  3   experience  20 non-null     int64
#  4   salary      20 non-null     int64
#  5   city        20 non-null     object
#  6   education   20 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.2+ KB
#              age  experience        salary
# count  20.000000   20.000000     20.000000
# mean   28.300000    4.600000  37950.000000
# std     6.053272    2.741494  16047.544492
# min    19.000000    1.000000  18000.000000
# 25%    23.750000    2.750000  25750.000000
# 50%    27.500000    4.000000  33500.000000
# 75%    32.250000    6.250000  46250.000000
# max    40.000000   10.000000  70000.000000

# %%
plt.hist(df['salary'])
plt.title("Salary Distribution")
plt.show()

# %%
sns.countplot(x='department', data=df)
plt.title("Department Count")
plt.show()

# %%
plt.scatter(df['experience'], df['salary'])
plt.title("Experience vs Salary")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()
